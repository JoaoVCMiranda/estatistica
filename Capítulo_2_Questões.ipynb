# %%
from descritiva import *
from graficos import *

# %% [markdown]
# # Exemplos do capítulo 2

# %%
dados_pag_11 = [2,4,2,1,2,3,1,0,5,1,0,1,1,1,2,0,1,3,0,1,2]
f_pag_11 = get_frequencias_relativas(dados_pag_11)
barplot(f_pag_11)

# %%
freq_acuml_pag_12 = get_frequencias_relativas_acumuladas(dados_pag_11)
barplot(freq_acuml_pag_12)

# %%
dados_pag_13 = [21.5, 21.4, 21.8, 21.5, 21.6, 
                21.7, 21.6, 21.4, 21.2, 21.7, 
                21.3, 21.5, 21.7, 21.4, 21.4, 
                21.5, 21.9, 21.6, 21.3, 21.5, 
                21.4, 21.5, 21.6, 21.9, 21.5]

barplot(
    get_frequencias(
        discretizar(
            dados_pag_13
        ) 
    ),
    h = get_precisao(dados_pag_13)
)

# %%
freq = get_frequencias(discretizar(dados_pag_13))
print(freq)
poligono_frequencias(freq)
# Out:
# {21.2: 1, 21.3: 2, 21.400000000000002: 5, 21.500000000000004: 7, 21.600000000000005: 4, 21.700000000000006: 3, 21.800000000000008: 1, 21.90000000000001: 2}

# %%
print(get_frequencias_relativas_acumuladas(dados_pag_13))
poligono_frequencias(get_frequencias_relativas_acumuladas(dados_pag_13))
# Out:
# {21.2: 0.04, 21.3: 0.12, 21.4: 0.32, 21.5: 0.6000000000000001, 21.6: 0.7600000000000001, 21.7: 0.8800000000000001, 21.8: 0.9200000000000002, 21.9: 1.0000000000000002}

# %% [markdown]
# # Execícos de Aplicação 2.2.4

# %% [markdown]
# ## 1.

# %%
dados_pag_19_1 = [1,4,0,1,1,7,3,2,0,
                  0,1,4,0,5,2,1,3,3]
barplot(get_frequencias(dados_pag_19_1), title="Histograma")

# %%
poligono_frequencias(get_frequencias(dados_pag_19_1))

# %%
print(get_frequencias_acumuladas(dados_pag_19_1))
poligono_frequencias_acumuladas(get_frequencias_acumuladas(dados_pag_19_1))
# Out:
# {0: 4, 1: 9, 2: 11, 3: 14, 4: 16, 5: 17, 7: 18}

# %% [markdown]
# ## 2.

# %%
dados_pag_19_2 = [2,0,1,2,3,1,6,1,0,0,
                  1,2,2,1,2,0,1,4,2,3,
                  0,1,0,2,1,2,4,1,1,1]
barplot(get_frequencias(dados_pag_19_2), title="Histograma # de dias por quantidade de acidentes")

# %%
import matplotlib.pyplot as plt
x = [i +1 for i in range(len(dados_pag_19_2))]
plt.title("Acidentes por dia")
plt.plot(x, dados_pag_19_2)

# %% [markdown]
# ## 3.

# %%
dados_tabela_2_6 = [
    61, 52, 53, 48, 55,
    65, 53, 56, 54, 46,
    43, 62, 48, 57, 57,
    53, 49, 50, 41, 54,
    55, 68, 61, 54, 48,
    51, 51, 44, 71, 63,
    58, 50, 64, 57, 49,
    55, 67, 53, 53, 55,
    59, 62, 54, 46, 52,
    56, 64, 55, 48, 51]
poligono_frequencias_acumuladas(get_frequencias_relativas_acumuladas(dados_tabela_2_6), title="Frequência relativa acumulada tempo de preenchimento < t ", xlabel="t(s)", ylabel="P(t0<t)")

# %% [markdown]
# ## 4.

# %%
dados_pag_19_4 = [
    64, 51, 28, 57, 8, 15, 59, 52,
    73, 36, 38, 25, 3, 28, 8,  63,
    44, 47, 42, 39, 65, 48, 54, 40,
    10, 45, 49, 2,  50, 47, 84, 16,
    43, 65, 19, 40, 38, 68, 45, 52,
    31, 79, 49, 22, 9,  6,  39, 44,
    51, 58, 65, 5,  56, 34, 41, 46,
    4,  45, 32, 60, 21, 12, 43, 59,
    25, 54, 33, 44, 9,  65, 41, 22,
    53, 73, 11, 3,  57, 28, 38, 15
]
barplot(get_frequencias(dados_pag_19_4))

# %%
poligono_frequencias(get_frequencias(dados_pag_19_4))

# %%
poligono_frequencias_acumuladas(get_frequencias_acumuladas(dados_pag_19_4), title="Frequência acumulada # de médias < m", xlabel="m", ylabel="# médias")

# %% [markdown]
# ## 5.

# %%
dados_pag_19_5 = [
    2.9, 7.5, 5.0, 11.6, 2.7, 7.9, 18.8, 3.8, 8.5, 4.4,
    12.9, 3.3, 7.4, 6.3, 2.6, 6.9, 5.6, 12.4, 16.0, 2.7,
    6.3, 4.4, 13.1, 4.8, 10.0, 0.4, 5.5, 16.2, 2.3, 9.5,
    4.5, 10.6, 3.2, 8.7, 9.0, 3.9, 9.2, 8.4, 0.8, 4.6,
    15.6, 7.1, 17.8, 4.5, 10.5, 5.3, 11.8, 2.3, 2.4, 7.5
]
h = 2
dados_discretos_pag_19_5 = discretizar(dados_pag_19_5, h) 
barplot(
    get_frequencias(dados_discretos_pag_19_5),
    h=h
)

# %%
poligono_frequencias_acumuladas(
    get_frequencias_relativas_acumuladas(dados_discretos_pag_19_5)
)

# %% [markdown]
# # 2.4 Exercícios Complementares

# %% [markdown]
# ## 4.

# %%
dados_pag_32_q4 = [75,77,80,70,78,
                   82,85,72,77,82]
me = media(dados_pag_32_q4)
md = mediana(dados_pag_32_q4)
mo = moda(dados_pag_32_q4)
var = variancia(dados_pag_32_q4)
des_pad = var**0.5
coef_var = des_pad/me * 100
print(me,md, mo, var, des_pad,  f'{coef_var:.2f}%')
# Out:
# 77.8 77.5 77 21.733333333333334 4.661902329879224 5.99%

# %% [markdown]
# ## 5.

# %%
dados_pag_32_q5 = [
    64.0, 61.0, 65.0, 43.0, 45.0, 54.0, 51.0, 74.0,
    30.0, 100.0, 91.0, 75.0, 78.0, 68.0, 80.0, 69.0,
    72.0, 27.0, 40.0, 93.0, 99.0, 94.0, 78.0, 72.0,
    59.0, 78.0, 95.0, 62.0, 42.0, 96.0, 100.0, 95.0,
    81.0, 84.0, 78.0, 103.0, 98.0, 60.0, 84.0, 91.0
]
dados_pag_32_q5 = discretizar(dados_pag_32_q5, 5)
poligono_frequencias(get_frequencias(dados_pag_32_q5))

# %%
poligono_frequencias_acumuladas(get_frequencias_acumuladas(dados_pag_32_q5))

# %% [markdown]
# ## 16.
# Pela medida de assimetria de Pearson, essa distribuição é moderadamente assimétrica
# $$
# 0.15\le|A|\le 1
# $$

# %%
dados_pag_35_q16 = [
    6.34, 6.38, 6.40, 6.30, 6.36, 6.36,
    6.38, 6.20, 6.42, 6.28, 6.38
]
print('coef assimetria',coeficiente_assimetria(dados_pag_35_q16))
assimetria_pearson = (media(dados_pag_35_q16)-moda(dados_pag_35_q16))/variancia(dados_pag_35_q16)**(0.5)
print(abs(assimetria_pearson))
# Out:
# coef assimetria 2.911783057150239
# 0.5457157159485502
